# %%
# Import basic data libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import libraries for data crawling
import re
from google_play_scraper import Sort, app, reviews

# %%
# Initialize the data crawler
rvws, token = reviews(
    app_id='free.vpn.unblock.proxy.turbovpn',
    lang='id',
    country='id',
    count=500,
    sort= Sort.MOST_RELEVANT,
    filter_score_with= None
)

# %%
text = pd.DataFrame(rvws)
text.head()
# Out:
#                                reviewId        userName  \
# 0  725f8e90-10fe-4287-a5bc-c9a1ddac28a2         Ditxzzx
# 1  9e0dd4ff-2ec2-4d49-ace5-53f9dbfa4787       Gugun Bae
# 2  db34532c-3c70-44d6-94e5-82c6f6624d41      Dalla Cell
# 3  58d8b218-f994-4e95-a5ad-a5d14bcbf090  Muhammad Yusuf
# 4  8eed60c8-8980-405f-ab9b-2689c914b66e     Didi Keling
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0  Aplikasi ini bagus untuk mempercepat koneksi i...      4             17
# 1  Good berkat aplikasi ini lancar anda belum tau...      5            690
# 2  Tolong tingkat kn lagi ...,kadang lambat dan l...      4              5
# ...

# %%
# Selecting the data
df = text[['userName', 'content', 'score', 'at']]
df
# Out:
#             userName                                            content  \
# 0            Ditxzzx  Aplikasi ini bagus untuk mempercepat koneksi i...
# 1          Gugun Bae  Good berkat aplikasi ini lancar anda belum tau...
# 2         Dalla Cell  Tolong tingkat kn lagi ...,kadang lambat dan l...
# 3     Muhammad Yusuf  Bagus dan top lah aplikasinya.... Tapi tolong ...
# 4        Didi Keling  Apk nya parah banget... Udah lemot.. download ...
# ..               ...                                                ...
# 495       email tika  Serius nanya yg pada review oke tuh gmn carany...
# 496    Hafiz Hidayah  Banyak yg mengalami kendala? Mungkin disebabka...
# 497        Koeda 461  Easy to use,ui simpel,kenapa kok opsi protokol...
# 498         Zwen All  Sering terputus sendiri, banyak iklan (iklan b...
# 499  Pengguna Google  dalam jangkauan 4G kadang lemot dan videonya s...
#
#      score                  at
# 0        4 2024-06-14 15:53:48
# 1        5 2024-05-27 09:50:03
# ...

# %%
# Removing emoji
import demoji

def clean_text(text):
    text = demoji.replace(text, '')
    return text

df['content'] = df['content'].apply(clean_text)
df['content'] = df['content'].str.lower()
df.head()
# Out:
# C:\Users\septi\AppData\Local\Temp\ipykernel_13748\1613762139.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['content'] = df['content'].apply(clean_text)
# C:\Users\septi\AppData\Local\Temp\ipykernel_13748\1613762139.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['content'] = df['content'].str.lower()
#          userName                                            content  score  \
# 0         Ditxzzx  aplikasi ini bagus untuk mempercepat koneksi i...      4
# ...

# %%
# Save the data to csv
df.to_csv('turbo-vpn-reviews.csv', index=False)
